# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t= np.linspace(-np.pi, np.pi, 1000)
s= t + 3

plt.figure(figsize=(6, 4), dpi=150)
plt.plot(t, s)
plt.title("Señal original F(x)")
plt.xlabel("Tiempo (s)")
plt.ylabel("F(x)")
# Out:
# Text(0, 0.5, 'F(x)')

# %%
#Por medio de integración, 50 coeficientes de la serie de Fourier.

N = 50
s_n = np.ndarray(shape=(N, len(t)))
a = np.zeros(N)
b = np.zeros(N)
for i in range(N):
# Integrando para obtener an y bn
  a[i] = 2/T * np.trapz(s * np.cos(2 * np.pi /T * i * t), t)
  b[i] = 2/T * np.trapz(s * np.sin(2 * np.pi /T * i * t), t)
# Obteniendo f(t) cuando n=1, 2, 3, ...
  cos_n = a[i] * np.cos(2 * np.pi/T * i * t)
  sin_n = b[i] * np.sin(2 * np.pi/T * i * t)
  s_n[i][:] = cos_n + sin_n
  s_r = np.zeros_like(t)
for n in range(N):
  s_r = s_r + s_n[n][:]

plt.figure(figsize=(6, 4), dpi=150)
plt.plot(t, s_r)

# %%
plt.plot(a)
plt.title("Señal de a(n)")
plt.ylabel("a(n)")
# Out:
# Text(0, 0.5, 'a(n)')

# %%
plt.plot(b)
plt.title("Señal de b(n)")
plt.ylabel("b(n)")
# Out:
# Text(0, 0.5, 'b(n)')

# %%
#Por medio de integración, 10 coeficientes de la serie de Fourier.

N = 10
s_n = np.ndarray(shape=(N, len(t)))
a = np.zeros(N)
b = np.zeros(N)
for i in range(N):
# Integrando para obtener an y bn
  a[i] = 2/T * np.trapz(s * np.cos(2 * np.pi /T * i * t), t)
  b[i] = 2/T * np.trapz(s * np.sin(2 * np.pi /T * i * t), t)
# Obteniendo f(t) cuando n=1, 2, 3, ...
  cos_n = a[i] * np.cos(2 * np.pi/T * i * t)
  sin_n = b[i] * np.sin(2 * np.pi/T * i * t)
  s_n[i][:] = cos_n + sin_n
  s_r = np.zeros_like(t)
for n in range(N):
  s_r = s_r + s_n[n][:]

plt.figure(figsize=(6, 4), dpi=150)
plt.plot(t, s_r)

# %%
#Por medio de integración, 10 coeficientes de la serie de Fourier.

N = 60
s_n = np.ndarray(shape=(N, len(t)))
a = np.zeros(N)
b = np.zeros(N)
for i in range(N):
# Integrando para obtener an y bn
  a[i] = 2/T * np.trapz(s * np.cos(2 * np.pi /T * i * t), t)
  b[i] = 2/T * np.trapz(s * np.sin(2 * np.pi /T * i * t), t)
# Obteniendo f(t) cuando n=1, 2, 3, ...
  cos_n = a[i] * np.cos(2 * np.pi/T * i * t)
  sin_n = b[i] * np.sin(2 * np.pi/T * i * t)
  s_n[i][:] = cos_n + sin_n
  s_r = np.zeros_like(t)
for n in range(N):
  s_r = s_r + s_n[n][:]

plt.figure(figsize=(6, 4), dpi=150)
plt.plot(t, s_r)

# %%
#Por medio de integración, 360 coeficientes de la serie de Fourier.

N = 360
s_n = np.ndarray(shape=(N, len(t)))
a = np.zeros(N)
b = np.zeros(N)
for i in range(N):
# Integrando para obtener an y bn
  a[i] = 2/T * np.trapz(s * np.cos(2 * np.pi /T * i * t), t)
  b[i] = 2/T * np.trapz(s * np.sin(2 * np.pi /T * i * t), t)
# Obteniendo f(t) cuando n=1, 2, 3, ...
  cos_n = a[i] * np.cos(2 * np.pi/T * i * t)
  sin_n = b[i] * np.sin(2 * np.pi/T * i * t)
  s_n[i][:] = cos_n + sin_n
  s_r = np.zeros_like(t)
for n in range(N):
  s_r = s_r + s_n[n][:]

plt.figure(figsize=(6, 4), dpi=150)
plt.plot(t, s_r)

# %%
#Por medio de integración, 10 coeficientes de la serie de Fourier.

N = 750
s_n = np.ndarray(shape=(N, len(t)))
a = np.zeros(N)
b = np.zeros(N)
for i in range(N):
# Integrando para obtener an y bn
  a[i] = 2/T * np.trapz(s * np.cos(2 * np.pi /T * i * t), t)
  b[i] = 2/T * np.trapz(s * np.sin(2 * np.pi /T * i * t), t)
# Obteniendo f(t) cuando n=1, 2, 3, ...
  cos_n = a[i] * np.cos(2 * np.pi/T * i * t)
  sin_n = b[i] * np.sin(2 * np.pi/T * i * t)
  s_n[i][:] = cos_n + sin_n
  s_r = np.zeros_like(t)
for n in range(N):
  s_r = s_r + s_n[n][:]

plt.figure(figsize=(6, 4), dpi=150)
plt.plot(t, s_r)
